# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title.

# %%
x=[0,10,20,30,40,50,60,70,80]
y=[0,20,40,60,80,100,120,140,160]
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Draw a line')
# Out:
# Text(0.5, 1.0, 'Draw a line')

# %% [markdown]
# #### 2.Write a Python program to draw a line using given axis values with suitablelabel in the x axis , y axis and a title.

# %%
x=[1,2,3]
y=[2.0,4,1]
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Sample Graph')
# Out:
# Text(0.5, 1.0, 'Sample Graph')

# %% [markdown]
# #### 3. Write a Python program to draw a line using given axis values taken from a text file, with suitable label in the x axis, y axis and a title.

# %%
with open('test.txt', 'r') as f:
    x = []
    y = []
    for line in f:
        i, j = map(float, line.split())
        x.append(i)
        y.append(j)

plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Sample Graph')
# Out:
# Text(0.5, 1.0, 'Sample Graph')

# %% [markdown]
# #### 4. Write a Python program to draw line charts of the financial data of Alphabet Inc. between October 3, 2016 to October 7, 2016.

# %%
df = pd.read_csv("asignment4/fdata.csv")
df['Date']=pd.to_datetime(df['Date'])
# Out:
# C:\Users\DAI.STUDENTSDC\AppData\Local\Temp\ipykernel_7860\318494969.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date']=pd.to_datetime(df['Date'])

# %%
df.plot(x = 'Date', y = ['Open','High','Low','Close'])
# Out:
# <Axes: xlabel='Date'>

# %%
plt.plot(df['Date'], df['Open'], label='Open')
plt.plot(df['Date'], df['High'], label='High')
plt.plot(df['Date'], df['Low'], label='Low')
plt.plot(df['Date'], df['Close'], label='Close')
plt.legend()
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# #### 5. Write a Python program to plot two or more lines on same plot with suitable legends of each line.

# %%
x = [10, 20, 30]
y1 = [40, 10, 30]
y2= [20, 40, 10]
plt.plot(x,y1, label= 'line-1')
plt.plot(x,y2, label = 'line-2')
plt.legend()
plt.title("two or more lines on same plot with suitable legends")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
# #### 6. Write a Python program to plot two or more lines with legends, different widths and colors.

# %%
x = [10, 20, 30]
y1 = [40, 10, 30]
y2= [20, 40, 10]
plt.plot(x,y1,lw = 3, label= 'line-1-width-3')
plt.plot(x,y2, lw = 5, label = 'line-2-width-5')
plt.legend()
plt.title("two or more lines on same plot with suitable legends")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
# #### 7. Write a Python program to plot two or more lines with different styles.

# %%
x = [10, 20, 30]
y1 = [40, 10, 30]
y2= [20, 40, 10]
plt.plot(x,y1, ls = ':',label= 'line-1-dotted')
plt.plot(x,y2, ls = '--',  label = 'line-2-dashed')
plt.legend()
plt.title("two or more lines on same plot with suitable legends")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
# #### 8. Write a Python program to plot two or more lines and set the line markers.

# %%
x = [10, 20, 30]
y1 = [40, 10, 30]
y2= [20, 40, 10]
plt.plot(x,y1, ls = ':', marker = 'o', label= 'line-1-dotted')
plt.plot(x,y2, ls = '--', marker = '*',  label = 'line-2-dashed')
plt.legend()
plt.title("two or more lines on same plot with suitable legends")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.xlim(10,31)
plt.ylim(10,41)
plt.show()

# %% [markdown]
# #### 9. Write a Python program to display the current axis limits values and set new axis values.

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)


plt.plot(x, y)
plt.show()

# %%
# Retrieve current axis limits
plt.plot(x,y)
current_x_limits = plt.gca().get_xlim()  # Get x-axis limits
current_y_limits = plt.gca().get_ylim()  # Get y-axis limits

print(f"Current X-axis limits----------------> {current_x_limits}")
print(f"Current Y-axis limits----------------> {current_y_limits}")

# Set new axis limits
plt.xlim(0, 12)
plt.ylim(-2, 2)

plt.show()
# Out:
# Current X-axis limits----------------> (-0.5, 10.5)
# Current Y-axis limits----------------> (-1.0993384025373631, 1.0996461858110391)

# %% [markdown]
# #### 10. Write a Python program to plot quantities which have an x and y position.

# %%
x = np.random.randint(2,10,5)
y = np.random.randint(5,30,5)
x1 = np.random.randint(2,10,5)
y1= np.random.randint(5,30,5)
quantities = [5,15,25,35,45]
quantities2 = [10,20,30,40,50]
plt.scatter(x, y, s=quantities, marker='o', label='Group 1')

plt.scatter(x1, y1, s=quantities2, c='r', alpha=0.6, marker='*', label='Group 2')

# %% [markdown]
# #### 11. Write a Python program to plot several lines with different format styles in one command using arrays.

# %%
x = np.arange(0., 5., 0.2)


plt.plot(x, x, 'g--', x, x**2, 'bs', x, x**3, 'r^')
plt.show()

# %% [markdown]
# #### 12. Write a Python program to create multiple types of charts (a simple curve and plot some quantities) on a single set of axes.

# %%
df
# Out:
#         Date        Open        High         Low       Close
# 0 2016-10-03  774.250000  776.065002  769.500000  772.559998
# 1 2016-10-04  776.030029  778.710022  772.890015  776.429993
# 2 2016-10-05  779.309998  782.070007  775.650024  776.469971
# 3 2016-10-06  779.000000  780.479980  775.539978  776.859985
# 4 2016-10-07  779.659973  779.659973  770.750000  775.080017

# %%
import matplotlib.dates as mdates

# %%
plt.plot(df.Date, df.Close, c = 'r', marker = 'o')
plt.xticks(rotation = 45)

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

# %% [markdown]
# #### 13. Write a Python program to display the grid and draw line charts of the
# - closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016.
# - Customized the grid lines with linestyle -, width .5. and color blue.

# %%
plt.plot(df.Date, df.Close, c = 'b', marker = 'o', ls = '-', lw = 0.5)
plt.xticks(rotation = 45)
plt.grid()
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

# %% [markdown]
# #### 14. Write a Python program to display the grid and draw line charts of the
# closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016.
# Customized the grid lines with rendering with a larger grid (major grid) and a
# smaller grid (minor grid).Turn on the grid but turn off ticks.

# %%
plt.plot(df.Date, df.Close, c = 'b', marker = 'o', ls = '-', lw = 0.5)
plt.xticks(rotation = 45)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

# %% [markdown]
# #### 15. Write a Python program to create multiple plots.

# %%
fig = plt.figure()

plt.subplot(2, 1, 1)
plt.xticks(()), plt.yticks(())

plt.subplot(2, 3, 4)
plt.xticks(())
plt.yticks(())

plt.subplot(2, 3, 5)
plt.xticks(())
plt.yticks(())

plt.subplot(2, 3, 6)
plt.xticks(())
plt.yticks(())

plt.show()
